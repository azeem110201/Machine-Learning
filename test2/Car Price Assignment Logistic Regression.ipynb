# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('CarPrice_Assignment.csv')

# %%
raw_data.head(10)
# Out:
#                     CarName  fueltype  aspiration  doornumber      carbody  \
# 0        alfa-romero giulia         1           1           2  convertible
# 1       alfa-romero stelvio         1           1           2  convertible
# 2  alfa-romero Quadrifoglio         1           1           2    hatchback
# 3               audi 100 ls         1           1           4        sedan
# 4                audi 100ls         1           1           4        sedan
# 5                  audi fox         1           1           2        sedan
# 6                audi 100ls         1           1           4        sedan
# 7                 audi 5000         1           1           4        wagon
# 8                 audi 4000         1           0           4        sedan
# 9       audi 5000s (diesel)         1           0           2    hatchback
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# 0               1       88.6      168.8      64.1       48.8  ...
# ...

# %%
raw_data = raw_data.drop(['car_ID'],axis=1)

# %%
raw_data = raw_data.drop(['symboling'],axis=1)

# %%
raw_data.head()
# Out:
#                     CarName fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# 0        rwd          front       88.6      168.8      64.1  ...         130
# 1        rwd          front       88.6      168.8      64.1  ...         130
# 2        rwd          front       94.5      171.2      65.5  ...         152
# 3        fwd          front       99.8      176.6      66.2  ...         109
# 4        4wd          front       99.4      176.6      66.4  ...         136
#
# ...

# %%
raw_data['fueltype'] = raw_data['fueltype'].map({'gas':1,'diesel':0})

# %%
raw_data['aspiration'] = raw_data['aspiration'].map({'std':1,'turbo':0})

# %%
raw_data['doornumber'] = raw_data['doornumber'].map({'two':2,'four':4})

# %%
raw_data = raw_data.drop(['drivewheel'],axis=1)

# %%
raw_data['enginelocation'] = raw_data['enginelocation'].map({'front':1,'rear':0})

# %%
raw_data = raw_data.drop(['fuelsystem'],axis=1)

# %%
raw_data['enginetype']
# Out:
# 0      dohc
# 1      dohc
# 2      ohcv
# 3       ohc
# 4       ohc
#        ...
# 200     ohc
# 201     ohc
# 202    ohcv
# 203     ohc
# 204     ohc
# Name: enginetype, Length: 205, dtype: object
